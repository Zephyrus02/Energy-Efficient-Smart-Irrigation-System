# %%
# !pip install blynklib
# !pip install blynk-library-python
# Out:
# Requirement already satisfied: blynklib in e:\python\lib\site-packages (0.2.6)
# Collecting blynk-library-python
#   Downloading blynk-library-python-0.2.0.tar.gz (5.3 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: blynk-library-python
#   Building wheel for blynk-library-python (setup.py): started
#   Building wheel for blynk-library-python (setup.py): finished with status 'done'
#   Created wheel for blynk-library-python: filename=blynk_library_python-0.2.0-py3-none-any.whl size=3734 sha256=80ef0b6da9049dab9aa9bb103b10cc00e59b2d32d96dcb58160a81bb7bd781c2
#   Stored in directory: c:\users\rog strix\appdata\local\pip\cache\wheels\1f\83\20\1b14c1bd403e97846354d63b8db0c16ec60f2134131104d87e
# Successfully built blynk-library-python
# Installing collected packages: blynk-library-python
# Successfully installed blynk-library-python-0.2.0

# %%
import BlynkLib
# Out:
#     ___  __          __
#    / _ )/ /_ _____  / /__
#   / _  / / // / _ \/  '_/
#  /____/_/\_, /_//_/_/\_\
#         /___/ for Python v0.2.0 (Windows)

# %%
import requests

# Replace with your actual Blynk API key and virtual pin
BLYNK_API_KEY = "BMHkEagYF22NisUfZ2ee-JrllX4P3w99"
VIRTUAL_PIN = 0

# Construct the URL
url = f"https://blr1.blynk.cloud/external/api/get?token={BLYNK_API_KEY}&v{VIRTUAL_PIN}"

# Send the HTTP GET request to retrieve the value
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    value = response.text
    print(f"Value read from Blynk app: {value}")
else:
    print(f"Error reading value. Status code: {response.status_code}")
# Out:
# Value read from Blynk app: 40

# %%
import requests

# Replace with your actual Blynk API key and virtual pin
BLYNK_API_KEY = "BMHkEagYF22NisUfZ2ee-JrllX4P3w99"
VIRTUAL_PIN = 0
NEW_VALUE = 40  # Replace with the value you want to set

# Construct the URL with the value in the query parameters
url = f"https://blr1.blynk.cloud/external/api/update?token={BLYNK_API_KEY}&v{VIRTUAL_PIN}={NEW_VALUE}"

# Send the HTTP GET request to update the value
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    print(f"Value {NEW_VALUE} updated successfully for pin V{VIRTUAL_PIN}")
else:
    print(f"Error updating value. Status code: {response.status_code}")
    print(response.text)  # Print the response content for further investigation
    print(url)
# Out:
# Value 40 updated successfully for pin V0

# %%
import sklearn

print('The scikit-learn version is {}.'.format(sklearn.__version__))
# Out:
# The scikit-learn version is 1.4.0.

# %% [markdown]
# # Final combined code

# %%
import joblib
import pandas as pd
import requests
import BlynkLib

# %%
BLYNK_API_KEY = "_Dc8Y5MGHBEZFUp9A1b4MofKsXmReYoN"
VIRTUAL_PIN0 = 0
VIRTUAL_PIN1 = 1
VIRTUAL_PIN2 = 2

url1 = f"https://blr1.blynk.cloud/external/api/get?token={BLYNK_API_KEY}&v{VIRTUAL_PIN0}"
url2 = f"https://blr1.blynk.cloud/external/api/get?token={BLYNK_API_KEY}&v{VIRTUAL_PIN1}"
url3 = f"https://blr1.blynk.cloud/external/api/get?token={BLYNK_API_KEY}&v{VIRTUAL_PIN2}"


temp = requests.get(url1)
humd = requests.get(url2)
mois = requests.get(url3)

print(temp.text, mois.text, humd.text)
# Out:
# 25 99 0

# %%
data = {
    'CropDays': [29.0],
    'SoilMoisture': [mois.text],
    'temperature': [temp.text],
    'Humidity': [humd.text],
    'CropType': [7.0]
}

df = pd.DataFrame(data)
df
# Out:
#    CropDays SoilMoisture                                        temperature  \
# 0      29.0           99  {"error":{"message":"Requested pin doesn't hav...
#
#   Humidity  CropType
# 0        0       7.0

# %%
dtree = joblib.load('decision_tree.joblib')

# %%
y_pred = dtree.predict(df)

# %%
print(y_pred)
# Out:
# [0]

# %%
VIRTUAL_PIN3 = 3
url = f"https://blr1.blynk.cloud/external/api/update?token={BLYNK_API_KEY}&v{VIRTUAL_PIN3}={y_pred[0]}"

response = requests.get(url)

if response.status_code == 200:
    print(f"Value {NEW_VALUE} updated successfully for pin V{VIRTUAL_PIN}")
else:
    print(f"Error updating value. Status code: {response.status_code}")
    print(response.text)  # Print the response content for further investigation
    print(url)
# Out:
# Value 40 updated successfully for pin V0

# %% [markdown]
# # Combined code

# %%
import joblib
import pandas as pd
import requests
import BlynkLib
import time

BLYNK_API_KEY = "_Dc8Y5MGHBEZFUp9A1b4MofKsXmReYoN"
while(True):
    VIRTUAL_PIN0 = 0
    VIRTUAL_PIN1 = 1
    VIRTUAL_PIN2 = 2
    VIRTUAL_PIN3 = 3
    
    url1 = f"https://blr1.blynk.cloud/external/api/get?token={BLYNK_API_KEY}&v{VIRTUAL_PIN0}"
    url2 = f"https://blr1.blynk.cloud/external/api/get?token={BLYNK_API_KEY}&v{VIRTUAL_PIN1}"
    url3 = f"https://blr1.blynk.cloud/external/api/get?token={BLYNK_API_KEY}&v{VIRTUAL_PIN2}"
    
    temp = requests.get(url1)
    humd = requests.get(url2)
    mois = requests.get(url3)
    
    data = {
        'CropDays': [29.0],
        'SoilMoisture': [mois.text],
        'temperature': [temp.text],
        'Humidity': [humd.text],
        'CropType': [7.0]
    }
    
    df = pd.DataFrame(data)
    print(df)
    
    dtree = joblib.load('decision_tree.joblib')
    y_pred = dtree.predict(df)
    print(y_pred)
    
    VIRTUAL_PIN3 = 3
    url = f"https://blr1.blynk.cloud/external/api/update?token={BLYNK_API_KEY}&v{VIRTUAL_PIN3}={y_pred[0]}"
    
    response = requests.get(url)
    
    if response.status_code == 200:
        print(f"Value {y_pred[0]} updated successfully for pin V{VIRTUAL_PIN3}")
    else:
        print(f"Error updating value. Status code: {response.status_code}")
        print(response.text)  # Print the response content for further investigation
        print(url)
    time.sleep(1)
# Out:
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0         1000          28       87       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0         1000          28       87       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0         1000          28       87       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0         1000          28       87       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0         1000          28       87       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0         1000          28       87       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0         1000          28       87       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0         1000          28       87       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0         1000          28       87       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          502          28       87       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          508          28       87       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          506          28       87       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          500          28       87       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          489          28       87       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          445          28       87       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          427          28       87       7.0
# [0]
# Value 0 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          410          28       87       7.0
# [0]
# Value 0 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          414          28       88       7.0
# [0]
# Value 0 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          416          28       87       7.0
# [0]
# Value 0 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          423          28       87       7.0
# [0]
# Value 0 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          427          28       87       7.0
# [0]
# Value 0 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          429          28       87       7.0
# [0]
# Value 0 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          434          28       87       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          438          28       87       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          442          28       87       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          448          28       87       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          398          28       87       7.0
# [0]
# Value 0 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          357          28       88       7.0
# [0]
# Value 0 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          375          28       88       7.0
# [0]
# Value 0 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          907          28       88       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          915          28       88       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0         1000          28       88       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0         1000          28       88       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0         1000          28       88       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0         1000          28       88       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          290          28       88       7.0
# [0]
# Value 0 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          430          28       90       7.0
# [0]
# Value 0 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          434          28       90       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          439          28       90       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          445          28       90       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          448          28       90       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          452          28       90       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          457          28       90       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          453          28       90       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          460          28       90       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          463          28       90       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          465          28       90       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          468          28       90       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          469          28       90       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          470          28       90       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          471          28       90       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          472          28       90       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          474          28       90       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          474          28       90       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          474          28       90       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          475          28       90       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          475          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          476          28       91       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          476          28       91       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          476          28       91       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          477          28       91       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          477          28       91       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          478          28       91       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          478          28       91       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          478          28       91       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          478          28       91       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          478          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          478          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          480          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          480          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          480          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          480          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          480          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          480          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          480          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          480          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          481          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          481          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          481          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          481          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          481          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          481          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          481          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          481          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          481          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          481          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          481          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          481          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          481          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       92       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          481          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          481          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          483          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0          482          28       94       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0         1000          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0         1000          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0         1000          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
#    CropDays SoilMoisture temperature Humidity  CropType
# 0      29.0         1000          28       93       7.0
# [1]
# Value 1 updated successfully for pin V3
